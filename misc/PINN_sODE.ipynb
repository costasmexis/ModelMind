# %% [markdown]
# ### Very Simple Example (single reaction)

# %%
import functools
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import seaborn as sns
from tqdm import tqdm
from scipy.integrate import solve_ivp, odeint

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

sns.set_theme()
torch.manual_seed(42)

# %%
# Define the system of ODEs
def model(y, t, k1, k2):
    dy1dt = -k1 * y[0]
    dy2dt = k1 * y[0] - k2 * y[1]
    return [dy1dt, dy2dt]

y0 = [1, 0]  # Initial conditions
T_START = 0
T_END = 2
t = np.linspace(T_START, T_END, 100)  # Adjust the time range as needed
k1 = 5
k2 = 1
solution = odeint(model, y0, t, args=(k1,k2))

# %%
# Analytic ODE solution
z_1 = lambda t: np.exp(-5 * t)
z_2 = lambda t: 5/4 * np.exp(-5 * t) * (-1 + np.exp(4 * t))

# Create true data
t_true = torch.from_numpy(t).float().view(-1,1).to(DEVICE)
y_true = torch.from_numpy(solution).float().to(DEVICE)

# Make training data
n_samples = 10
t_train = torch.linspace(T_START, 2, n_samples).view(-1,1).requires_grad_(True).to(DEVICE)
y_train_1 = z_1(t_train.cpu().detach().numpy())
y_train_2 = z_2(t_train.cpu().detach().numpy())
# Stack the two solutions using numpy 
y_train = np.hstack((y_train_1, y_train_2))

# Plot true and training data 
plt.figure(figsize=(4,3))
plt.plot(t_true.cpu().numpy(), y_true .cpu().numpy())
plt.plot(t_train.cpu().detach().numpy(), y_train[:,0], 'o')
plt.plot(t_train.cpu().detach().numpy(), y_train[:,1], 'o')
plt.show()

# %%
# Make a NN for u
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.fc1 = nn.Linear(1, 5)
        self.fc2 = nn.Linear(5, 10)
        self.fc3 = nn.Linear(10, 2)
        
        self.k2 = nn.Parameter(torch.tensor([1.0]))
        self.k1 = nn.Parameter(torch.tensor([1.0]))
        
    def forward(self, x):
        x = torch.tanh(self.fc1(x))
        x = torch.tanh(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
# Train data to tensor
ts_train = torch.tensor(t_train, requires_grad=True).float().to(DEVICE)
us_train = torch.tensor(y_train, requires_grad=True).float().to(DEVICE)
# Out:
# /tmp/ipykernel_37957/3687197062.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   ts_train = torch.tensor(t_train, requires_grad=True).float().to(DEVICE)

# %%
def residuals(t, model: nn.Module):
    t = torch.linspace(T_START, T_END, 500).view(-1,1).to(DEVICE)
    t.requires_grad = True  
    u = model(t).to(DEVICE)
    u_1 = u[:,0].view(-1,1)
    u_2 = u[:,1].view(-1,1)
    u_t_1  = torch.autograd.grad(u_1, t, grad_outputs=torch.ones_like(u_1), create_graph=True)[0]
    u_t_2  = torch.autograd.grad(u_2, t, grad_outputs=torch.ones_like(u_2), create_graph=True)[0]
    error_1 = u_t_1 - (-model.k1 * u_1)
    error_2 = u_t_2 - (model.k1 * u_1 - model.k2 * u_2)
    e_1 = torch.mean(error_1**2)
    e_2 = torch.mean(error_2**2)
    return e_1 + e_2

# %%
network = Network().to(DEVICE)
optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
criterion = nn.MSELoss()

EPOCHS = 10000
LOSS = []
for epoch in range(EPOCHS):
    
    u_pred = network.forward(ts_train)
    residual_pred = residuals(ts_train, network)
    
    loss = criterion(u_pred, us_train)
    loss += residual_pred
    
    LOSS.append(loss.item())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if epoch % 500 == 0:
        print(f'Epoch [{epoch}/{EPOCHS}] Loss: {loss}, k1: {network.k1.item()}, k2: {network.k2.item()}')
# Out:
# Epoch [0/10000] Loss: 0.23261938989162445, k1: 0.9990000128746033, k2: 0.9990000128746033
# Epoch [500/10000] Loss: 0.03494945913553238, k1: 1.1194032430648804, k2: 0.8655535578727722
# Epoch [1000/10000] Loss: 0.022045332938432693, k1: 1.6481119394302368, k2: 0.8373426198959351
# Epoch [1500/10000] Loss: 0.013865280896425247, k1: 2.143003225326538, k2: 0.9106647372245789
# Epoch [2000/10000] Loss: 0.007979759946465492, k1: 2.5819551944732666, k2: 0.9941446781158447
# Epoch [2500/10000] Loss: 0.004816428758203983, k1: 2.971956491470337, k2: 1.0419467687606812
# Epoch [3000/10000] Loss: 0.002948953304439783, k1: 3.3029849529266357, k2: 1.0554132461547852
# Epoch [3500/10000] Loss: 0.0018611601553857327, k1: 3.58589506149292, k2: 1.0532220602035522
# Epoch [4000/10000] Loss: 0.0011995621025562286, k1: 3.8299970626831055, k2: 1.0463032722473145
# Epoch [4500/10000] Loss: 0.000778455170802772, k1: 4.041601657867432, k2: 1.038562297821045
# Epoch [5000/10000] Loss: 0.0005079117836430669, k1: 4.225742816925049, k2: 1.03092360496521
# Epoch [5500/10000] Loss: 0.00035563891287893057, k1: 4.384634017944336, k2: 1.0240225791931152
# Epoch [6000/10000] Loss: 0.0002198295551352203, k1: 4.51915979385376, k2: 1.0181031227111816
# Epoch [6500/10000] Loss: 0.0002526948810555041, k1: 4.630843639373779, k2: 1.0131440162658691
# Epoch [7000/10000] Loss: 0.00010725954780355096, k1: 4.719692707061768, k2: 1.0094267129898071
# Epoch [7500/10000] Loss: 8.124795567709953e-05, k1: 4.7895283699035645, k2: 1.0064626932144165
# Epoch [8000/10000] Loss: 6.503667100332677e-05, k1: 4.843271732330322, k2: 1.0042779445648193
# Epoch [8500/10000] Loss: 5.472128395922482e-05, k1: 4.883127212524414, k2: 1.002750039100647
# Epoch [9000/10000] Loss: 4.770632222061977e-05, k1: 4.911947250366211, k2: 1.0017050504684448
# Epoch [9500/10000] Loss: 4.2359250073786825e-05, k1: 4.932959079742432, k2: 1.0010015964508057

# %%
# Plot u_pred vs ts
network.eval()
with torch.no_grad():
    u_pred = network(t_true)
    plt.figure(figsize=(4,3))
    plt.plot(t_true.cpu(), y_true.cpu(), label='True')
    plt.scatter(t_train.cpu(), y_train[:,0], label='Train', color='orange')
    plt.scatter(t_train.cpu(), y_train[:,1], label='Train', color='orange')
    plt.plot(t_true.cpu(), u_pred[:,0].cpu().numpy(), label='Pred', color='red')
    plt.plot(t_true.cpu(), u_pred[:,1].cpu().numpy(), label='Pred', color='red')
    plt.legend()
    plt.show()

# %%
network.k1, network.k2
# Out:
# (Parameter containing:
#  tensor([4.9477], requires_grad=True),
#  Parameter containing:
#  tensor([1.0006], requires_grad=True))
